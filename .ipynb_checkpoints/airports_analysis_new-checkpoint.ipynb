# %% [markdown]
# # Airport Delay Project

# %% [markdown]
# ## 1. Read the Data
#  OAG Data + WU Weather Data

# %%
import numpy as np
import pandas as pd
import datetime as datetime
import os
import matplotlib.pyplot as plt
from matplotlib import style
style.use('fivethirtyeight')
# %matplotlib inline
import statsmodels.formula.api as sm
# from IPython.core.interactiveshell import InteractiveShell # show all results of commands
# InteractiveShell.ast_node_interactivity = "all"

# %%
pwd #current working folder location
# Out:
# 'F:\\Dropbox\\Flight\\Code\\results'

# %%
path= 'F:\\Dropbox\\Flight\\DATA\\cleaned_data' #for load the data
path2= 'F:\\Dropbox\\Flight\\Code\\results' #for results saving
path
# Out:
# 'F:\\Dropbox\\Flight\\DATA\\cleaned_data'

# %%
os.chdir(path) # set the path as working directory.

# %%
df= pd.read_csv(path+'\\prepare_data.csv', parse_dates=['time','S_Dep_time','S_Arr_time'])
#parse data help the conversion string to datetime dtype.
# Out:
# C:\Users\Jukwan\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2717: DtypeWarning: Columns (82,86,88,90,92,94,96,98,100,106,118) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
# pd.set_option('display.max_rows', 8) # change presets for date preview
# pd.reset_option('display.max_rows')
df.head(3)
# Out:
#    Unnamed: 0  Unnamed: 0.1  Year  Quarter  Month  DayofMonth  DayOfWeek  \
# 0           0             0  2014        4     10          21          2
# 1           1             1  2014        4     10          21          2
# 2           2             2  2014        4     10          21          2
#
#    FlightDate UniqueCarrier  AirlineID  ...   RecordTypeFlag HourlyPrecip  \
# 0  2014-10-21            DL      19790  ...
# 1  2014-10-21            DL      19790  ...
# 2  2014-10-21            FL      20437  ...
#
#    HourlyPrecipFlag Altimeter AltimeterFlag                time  \
# 0                       29.93               2014-10-21 11:54:00
# 1                       29.93               2014-10-21 11:54:00
# 2                       29.93               2014-10-21 11:54:00
#
#               next_obs                  mid     id _merge
# 0  2014-10-21 12:54:00  2014-10-21 12:24:00  627.0   both
# 1  2014-10-21 12:54:00  2014-10-21 12:24:00  627.0   both
# 2  2014-10-21 12:54:00  2014-10-21 12:24:00  627.0   both
#
# [3 rows x 125 columns]

# %%
os.chdir(path2) # change directory.

# %%
# del df["Unnamed: 0"]
# del df["Unnamed: 0.1"]

# %% [markdown]
# # 2. Data Cleaning

# %%
# # indicate the data: north and south arrival date | departuredata

# # North departure
# mask=(df['Origin']== 'BOS') |(df['Origin']== 'PVD')|(df['Origin']== 'MHT') |(df['Origin']== 'ORH') ;mask
# df['north_dep']=mask.astype(int)
# print(df['north_dep'].value_counts())
# # North arrival
# mask=(df['Dest']== 'BOS') |(df['Dest']== 'PVD')|(df['Dest']== 'MHT') |(df['Dest']== 'ORH') ;mask
# df['north_arr']=mask.astype(int)
# print(df['north_arr'].value_counts())

# # indicate dep south
# mask=(df['Origin']== 'LAX') |(df['Origin']== 'SNA')|(df['Origin']== 'BUR') |(df['Origin']== 'LGB') ;mask
# df['south_dep']=mask.astype(int)
# print(df['south_dep'].value_counts())

# # south arrival
# mask=(df['Dest']== 'LAX') |(df['Dest']== 'SNA')|(df['Dest']== 'BUR') |(df['Dest']== 'LGB') ;mask
# df['south_arr']=mask.astype(int)
# print(df['south_arr'].value_counts())

# %%
## or can use mapping
# 1. make dictionary 
city_to_dic={ 'BOS': 'North', 'PVD' :'North', 'MHT':'North', 'ORH': 'North', \
             'LAX' : 'South', 'LGB':'South', 'BUR':'South','SNA':'South' }
# 2. maping the function
df['loca_dep']= df['Dest'].map(city_to_dic)
df['loca_arr']= df['Origin'].map(city_to_dic)
print(df['loca_dep'].value_counts())
print(df['loca_arr'].value_counts())
# Out:
# South    291643
# North    136436
# Name: loca_dep, dtype: int64
# South    291644
# North    136559
# Name: loca_arr, dtype: int64

# %%
# location north = 1 or south =0
mask = (df['loca_dep']=='North')|(df['loca_arr']=='North')
df['north'] =mask.astype(int)
df['north'].value_counts()
# Out:
# 0    565236
# 1    272995
# Name: north, dtype: int64

# %%
# dep:  departure = 1 arrrival = 0
df['con'].value_counts()
# Out:
# Dep    419182
# Arr    419049
# Name: con, dtype: int64

# %%
#  # of depature flights by airport

df['Origin'].value_counts().head(8).sort_index().plot()

# %%
 # of flights by airport
df['Origin'].where(df['con']=='Dep').value_counts().head(8).plot()
df['Dest'].where(df['con']=='Arr').value_counts().head(8).plot()

# %%
#Monthly Overall operation
df['Month'].value_counts().sort_index().plot()

# %%
## save decribe information and export to excel.
results=[]
df_dep = df[df['con']=='Dep']
df_arr = df[df['con']=='Arr']

desc_d =df_dep.groupby('Origin').describe()     
desc_a= df_arr.groupby('Dest').describe()  

results.append(desc_d)
results.append(desc_a)
append_results= pd.concat(results, axis= 0)
append_results.to_excel('description.xlsx')

# %%
delay_arr= df_arr.groupby(['Dest','ArrDel15'])

delay_arr.size().unstack().plot()

#ArrDel is arrival >=15

# %%
delay_dep= df_dep.groupby(['Origin','DepDel15'])

delay_dep.size().unstack().plot()

#ArrDel is arrival >=15

# %%
dep_lateby = df_dep.groupby(['Month','DepDel15','Origin'])
delay_dep= dep_lateby.size().unstack()

# %%
delay_dep
# Out:
# Origin             BOS     BUR      LAX     LGB    MHT   ORH    PVD     SNA
# Month DepDel15
# 1     0.0       6640.0  1420.0  14119.0   662.0  375.0  42.0  793.0  2686.0
#       1.0       1560.0   242.0   2971.0    98.0   67.0  11.0  156.0   471.0
# 2     0.0       4896.0  1239.0  12381.0   547.0  300.0  34.0  561.0  2426.0
#       1.0       2355.0   261.0   3054.0   120.0   66.0  12.0  168.0   457.0
# 3     0.0       7810.0  1499.0  13828.0   641.0  506.0  53.0  838.0  2880.0
#       1.0       1933.0   234.0   4005.0   117.0   96.0   7.0  190.0   462.0
# 4     0.0       7988.0  1427.0  14995.0   826.0  455.0  51.0  850.0  2638.0
#       1.0       1321.0   311.0   3412.0   103.0   75.0   8.0  127.0   549.0
# 5     0.0       7770.0  1488.0  15500.0   943.0  430.0  48.0  757.0  2612.0
#       1.0       1624.0   320.0   3736.0   112.0  110.0   7.0  187.0   680.0
# 6     0.0       7750.0  1397.0  14405.0   969.0  487.0  50.0  851.0  2500.0
#       1.0       1776.0   380.0   4836.0   119.0   99.0   6.0  144.0   800.0
# 7     0.0       7681.0     NaN  15862.0     NaN  514.0  43.0  899.0  2779.0
#       1.0       2251.0     NaN   4303.0     NaN  114.0  16.0  219.0   623.0
# 8     0.0       8266.0  1553.0  15203.0  1002.0  514.0  51.0  953.0  2760.0
#       1.0       1606.0   276.0   4077.0   150.0   85.0  10.0  164.0   589.0
# 9     0.0       8025.0  1475.0  14910.0   767.0  587.0  50.0  921.0  2751.0
#       1.0       1017.0   243.0   2549.0    68.0   53.0   7.0  107.0   467.0
# 10    0.0       8015.0  1585.0  15196.0   784.0  518.0  55.0  890.0  2851.0
#       1.0       1591.0   192.0   2896.0    83.0   76.0   7.0  113.0   507.0
# 11    0.0       7729.0  1407.0  13871.0   656.0  464.0  54.0  887.0  2596.0
#       1.0       1252.0   249.0   3070.0   129.0   48.0   4.0  101.0   538.0
# 12    0.0       7313.0  1186.0  12471.0   652.0  457.0  49.0  907.0  2345.0
#       1.0       1536.0   473.0   5095.0   158.0   66.0   9.0  114.0   861.0

# %%
arr_lateby = df_arr.groupby(['Month','ArrDel15','Dest'])
delay_arr= arr_lateby.size().unstack()

# %%
delay_arr.plot(kind='bar',stacked=True)

# %%
# Focus on 8 airports
df['airport']= np.where(df['con']=='Dep', df['Origin'],df['Dest'])
print(df['airport'].head())
df['delay']=np.where(df['con']=='Dep', df['DepDelay'],df['ArrDelay'])
# Out:
# 0    BOS
# 1    BOS
# 2    BOS
# 3    BOS
# 4    BOS
# Name: airport, dtype: object

# %%
flights_by_airport = df.pivot_table(index='FlightDate', columns='airport', values='FlightNum', aggfunc='count')
flights_by_airport.head(10)
# Out:
# airport       BOS    BUR     LAX   LGB   MHT  ORH   PVD    SNA
# FlightDate
# 2014-04-01  629.0  118.0  1228.0  53.0  31.0  4.0  70.0  218.0
# 2014-04-02  641.0  122.0  1237.0  55.0  31.0  4.0  70.0  222.0
# 2014-04-03  660.0  124.0  1276.0  65.0  32.0  4.0  69.0  228.0
# 2014-04-04  654.0  124.0  1278.0  68.0  32.0  4.0  68.0  228.0
# 2014-04-05  481.0   86.0  1076.0  56.0  30.0  4.0  61.0  164.0
# 2014-04-06  591.0  112.0  1219.0  64.0  30.0  4.0  65.0  204.0
# 2014-04-07  654.0  123.0  1266.0  66.0  31.0  4.0  67.0  228.0
# 2014-04-08  644.0  120.0  1248.0  55.0  35.0  4.0  64.0  218.0
# 2014-04-09  647.0  124.0  1258.0  57.0  35.0  4.0  64.0  224.0
# 2014-04-10  666.0  126.0  1291.0  66.0  36.0  4.0  64.0  230.0

# %%
# daily flight operations
flights_by_airport.plot(figsize=[20,6],stacked=True )

# %%
# mean delay by airport (seconds).
mean_delay_by_airport = df.pivot_table(index='FlightDate', columns='airport', values='delay', aggfunc='mean')

mean_delay_by_airport.head(5)
# Out:
# airport          BOS        BUR        LAX       LGB        MHT    ORH  \
# FlightDate
# 2014-04-01 -1.814103  12.953271  12.221122  1.254902  -0.935484 -10.00
# 2014-04-02 -4.132075   6.220339   7.234861 -5.381818  -1.064516  -9.50
# 2014-04-03  1.042748   7.272727  12.505929 -3.682540  16.156250  -9.50
# 2014-04-04  2.979876   8.639344  12.602041 -1.691176  11.875000   0.25
# 2014-04-05 -6.311850   0.151163   2.501866 -0.482143   5.300000   0.75
#
# airport          PVD        SNA
# FlightDate
# 2014-04-01 -1.828571  13.251208
# 2014-04-02  0.100000   5.843318
# 2014-04-03  6.086957  12.745614
# 2014-04-04  4.455882   9.261062
# 2014-04-05  4.081967  -1.585366

# %%
mean_delay_by_airport.plot(figsize=[10,6])

# %%
# mean arrival delay by airport (seconds).
mean_arr_delay_by_airport = df_arr.pivot_table(index='Month', columns='Dest', values='ArrDelay', aggfunc='mean')

mean_arr_delay_by_airport
# Out:
# Dest         BOS        BUR        LAX       LGB        MHT        ORH  \
# Month
# 1       6.911440   4.415812   1.738806 -1.052840   9.086957   5.074074
# 2      21.339967   6.655541   6.135450  5.484258   9.240437   8.933333
# 3       7.828851   1.934644   5.746131 -0.547270   9.570481  -0.100000
# 4       0.734661   5.628967   4.540542 -1.660173   7.307547   5.310345
# 5       5.253227   5.262168   5.075023 -2.875357  16.156134   2.654545
# 6       7.672737   9.750563  11.127176 -0.909761  17.698113   9.438596
# 7      11.340342        NaN   7.487485       NaN  14.111821  31.050847
# 8       4.746193   5.322581   7.202141  1.162186  10.055092  14.491803
# 9      -0.872685   3.933605   1.747792 -1.130852   2.124031   5.982759
# 10      6.731641   3.076271   2.137897 -1.915704   2.703204  -3.540984
# 11      2.104353   3.722659   3.083930  2.638107   3.984405  -6.413793
# 12      4.276888  12.940857  11.298349  3.740148   8.391473   0.543860
#
# Dest         PVD       SNA
# Month
# 1       7.249208  0.092816
# 2      10.940608  1.633299
# 3       6.378876 -1.265031
# 4       3.837281  0.871940
# 5      12.294243  2.843579
# 6      14.415493  8.274985
# 7      14.785842  4.263591
# 8      10.785139  3.783363
# 9       3.072195  1.626945
# 10      4.210369  1.846887
# 11      5.663296  1.488194
# 12      5.582515  7.911645

# %%
mean_arr_delay_by_airport.plot(figsize=[10,6])

# %%
mean_delay_by_airport = df.pivot_table(index='Month', columns='airport', values='delay', aggfunc='mean')
mean_delay_by_airport
# Out:
# airport        BOS        BUR        LAX       LGB        MHT        ORH  \
# Month
# 1         7.959484   5.567038   4.613343  1.189189   8.880546   6.364486
# 2        21.131773   7.080053   7.908330  7.607196  10.307377  10.175824
# 3         8.898087   3.252455   8.502219  2.145792  10.070539   0.508333
# 4         3.044411   6.219533   6.375279  0.363734   5.858491   2.153846
# 5         6.827535   5.960730   7.058652 -0.380342  12.416512   2.472727
# 6         8.191790   9.282015  11.799204  0.739190  13.295124   6.000000
# 7        12.177049        NaN   9.230739       NaN  12.600478  20.203390
# 8         5.901988   5.360306   8.875308  3.194794   8.726210   8.352459
# 9         1.167285   4.832314   3.809181  0.565947   2.325292   4.686957
# 10        6.974920   2.844657   4.249523 -0.275245   3.794440  -1.861789
# 11        3.734574   4.596799   5.604445  5.026165   3.160976  -5.525862
# 12        5.702787  13.318758  13.556246  6.141800   6.735322   1.539130
#
# airport        PVD        SNA
# Month
# 1         7.196203   3.136443
# 2        12.352374   4.062326
# 3         7.794175   1.937472
# 4         4.120123   3.908363
# 5        10.783741   5.622834
# 6        10.885370   9.397455
# 7        12.603850   5.976341
# 8         8.967323   5.846510
# 9         3.075499   3.332245
# 10        3.758225   3.947133
# 11        4.500253   4.266752
# 12        3.987249  11.091590

# %%
mean_delay_by_airport.plot(figsize=[10,6])

# %%
weather_by_airport = df.pivot_table(index='Month', columns='airport', values='WeatherDelay', aggfunc='mean')
weather_by_airport.head()
weather_by_airport.plot(figsize=[10,6])

# %%
weather_by_loc = df.pivot_table(index='Month', columns='north', values='WeatherDelay', aggfunc='mean')
weather_by_loc.head()
weather_by_loc.plot(figsize=[10,6])
#north = 1

# %%
hourly_operlation= df.pivot_table(index ='DepTimeBlk', columns= 'north', values= 'TailNum', aggfunc='count')
hourly_operlation.plot(figsize=[10,6])
hourly_operlation
hourly_operlation= df.pivot_table(index ='DepTimeBlk', columns= 'airport', values= 'TailNum', aggfunc='count')
hourly_operlation.plot(figsize=[10,6])

# %%
df.pivot_table(columns='FlightDate')
# Out:
# FlightDate              2014-04-01    2014-04-02    2014-04-03    2014-04-04  \
# ActualElapsedTime     1.567707e+02  1.567243e+02  1.591329e+02  1.586445e+02
# AirTime               1.349175e+02  1.349306e+02  1.358930e+02  1.352112e+02
# AirlineID             2.001276e+04  2.001280e+04  2.001958e+04  2.001815e+04
# ArrDel15              2.188450e-01  1.706383e-01  2.274784e-01  2.279623e-01
# ArrDelay              3.362571e+00  3.851064e-01  6.298231e+00  6.218122e+00
# ArrDelayMinutes       1.096309e+01  7.977447e+00  1.233361e+01  1.213530e+01
# ArrTime               1.500706e+03  1.494790e+03  1.482043e+03  1.483675e+03
# Arr_wban              3.004948e+04  2.980833e+04  2.987283e+04  2.988040e+04
# ArrivalDelayGroups   -1.993053e-01 -3.970213e-01 -7.610037e-02 -6.806068e-02
# CRSArrTime            1.507819e+03  1.501511e+03  1.498443e+03  1.496308e+03
# CRSDepTime            1.332888e+03  1.339465e+03  1.346129e+03  1.343551e+03
# CRSElapsedTime        1.597886e+02  1.605013e+02  1.620053e+02  1.621136e+02
# Cancelled             1.914079e-02  1.175483e-02  7.729862e-03  6.107492e-03
# CarrierDelay          1.230754e+01  1.280798e+01  1.203074e+01  1.418885e+01
# Date                  2.014040e+07  2.014040e+07  2.014040e+07  2.014040e+07
# DayOfWeek             2.000000e+00  3.000000e+00  4.000000e+00  5.000000e+00
# DayofMonth            1.000000e+00  2.000000e+00  3.000000e+00  4.000000e+00
# DepDel15              2.028609e-01  1.499575e-01  2.177122e-01  2.316824e-01
# DepDelay              7.629822e+00  4.841121e+00  9.548585e+00  1.001637e+01
# DepDelayMinutes       1.043780e+01  7.880204e+00  1.207503e+01  1.241957e+01
# DepTime               1.336609e+03  1.339560e+03  1.349374e+03  1.350125e+03
# Dep_wban              2.991526e+04  2.975311e+04  2.976375e+04  2.978638e+04
# DepartureDelayGroups -2.774166e-02 -2.366185e-01  8.036080e-02  9.660254e-02
# DestStateFips         1.847299e+01  1.855080e+01  1.846420e+01  1.844340e+01
# Distance              9.786963e+02  9.857422e+02  9.979247e+02  9.997887e+02
# DistanceGroup         4.356019e+00  4.385390e+00  4.436534e+00  4.442997e+00
# Div1AirportSeqID      1.282004e+06  1.448052e+06      ...       1.100652e+06
# Div1WheelsOn          4.100000e+02  1.257500e+03      ...       1.928000e+03
# DivActualElapsedTime  3.970000e+02  3.620000e+02      ...       3.730000e+02
# ...                            ...           ...      ...                ...
# Diverted              8.288438e-04  8.054772e-04      ...       8.896797e-04
# FirstDepTime          1.370273e+03  1.275000e+03      ...       1.134300e+03
# FlightNum             1.886227e+03  1.888182e+03      ...       1.882821e+03
# Flights               1.000000e+00  1.000000e+00      ...       1.000000e+00
# LateAircraftDelay     1.740000e+01  2.454586e+01      ...       1.952613e+01
# LongestAddGTime       2.381818e+01  2.050000e+01      ...       3.090000e+01
# Month                 4.000000e+00  4.000000e+00      ...       3.000000e+00
# NASDelay              1.025385e+01  8.709172e+00      ...       1.822125e+01
# OriginStateFips       1.844758e+01  1.848087e+01      ...       1.879048e+01
# Quarter               2.000000e+00  2.000000e+00      ...       1.000000e+00
# SecurityDelay         1.115385e-01  3.131991e-02      ...       1.132404e-01
# StationType           1.115872e+01  1.115787e+01      ...       1.115747e+01
# TaxiIn                6.808848e+00  7.214517e+00      ...       7.450180e+00
# TaxiOut               1.535044e+01  1.581022e+01      ...       1.735817e+01
# Time                  1.399705e+03  1.400004e+03      ...       1.446593e+03
# TotalAddGTime         2.381818e+01  2.050000e+01      ...       3.090000e+01
# Unnamed: 0            3.562661e+04  3.633633e+04      ...       3.584164e+04
# Unnamed: 0.1          6.626470e+03  7.227545e+03      ...       6.297711e+03
# WBAN                  2.718203e+04  2.717008e+04      ...       2.690876e+04
# WeatherDelay          5.000000e-02  3.017897e+00      ...       5.853659e-01
# WheelsOff             1.360441e+03  1.377192e+03      ...       1.410817e+03
# WheelsOn              1.481587e+03  1.492326e+03      ...       1.500212e+03
# Year                  2.014000e+03  2.014000e+03      ...       2.015000e+03
# delay                 3.002502e-01  5.793915e+00      ...       1.054623e+01
# id                    2.287580e+02  2.611740e+02      ...       5.913999e+02
# key                   2.581026e+05  2.664463e+05      ...       2.303940e+05
# new_id                2.287580e+02  2.611740e+02      ...       5.913999e+02
# north                 3.195193e-01  3.201772e-01      ...       3.345196e-01
# sa_time               1.497559e+03  1.496195e+03      ...       1.529322e+03
# sd_time               1.339610e+03  1.344585e+03      ...       1.387224e+03
#
# FlightDate              2015-03-23    2015-03-24    2015-03-25    2015-03-26  \
# ActualElapsedTime     1.632318e+02  1.593791e+02  1.615980e+02  1.658813e+02
# AirTime               1.385721e+02  1.358113e+02  1.372627e+02  1.402390e+02
# AirlineID             1.998627e+04  1.998280e+04  1.998162e+04  1.998884e+04
# ArrDel15              2.225494e-01  1.209262e-01  1.701858e-01  2.589212e-01
# ArrDelay              1.087000e+01 -9.318182e-01  2.066301e+00  9.378008e+00
# ArrDelayMinutes       1.734329e+01  6.704974e+00  9.081081e+00  1.556349e+01
# ArrTime               1.480265e+03  1.490438e+03  1.481518e+03  1.459352e+03
# Arr_wban              3.016224e+04  3.012206e+04  3.007367e+04  3.007532e+04
# ArrivalDelayGroups    2.128734e-01 -5.154374e-01 -3.437500e-01  1.439834e-01
# DepDelayMinutes       7.760239e+00
# DepTime               1.341618e+03
# Dep_wban              3.007109e+04
# DepartureDelayGroups -2.504266e-01
# DestStateFips         1.899873e+01
# Distance              1.001844e+03
# DistanceGroup         4.436125e+00
# Div1AirportID         1.246775e+04
# Div1AirportSeqID      1.246778e+06
# Div1WheelsOn          1.714250e+03
# DivActualElapsedTime  3.913333e+02
# ...                            ...
# Diverted              1.692047e-03
# FirstDepTime          1.345500e+03
# FlightNum             1.810342e+03
# Flights               1.000000e+00
# LateAircraftDelay     1.728354e+01
# LongestAddGTime       2.316667e+01
# Month                 3.000000e+00
# NASDelay              1.222866e+01
# OriginStateFips       1.909898e+01
# Quarter               1.000000e+00
# SecurityDelay         1.615854e-01
# StationType           1.116371e+01
# TaxiIn                7.414426e+00
# TaxiOut               1.649104e+01
# Time                  1.396606e+03
# TotalAddGTime         2.316667e+01
# Unnamed: 0            3.535277e+04
# Unnamed: 0.1          6.154406e+03
# WBAN                  2.713542e+04
# WeatherDelay          8.963415e-01
# WheelsOff             1.364815e+03
# WheelsOn              1.473404e+03
# Year                  2.015000e+03
# delay                 1.615286e+00
# id                    8.577069e+02
# key                   2.544704e+05
# new_id                8.577069e+02
# north                 3.489848e-01
# sa_time               1.491641e+03
# sd_time               1.339773e+03
#
# [64 rows x 365 columns]

# %%
# grouped_arr.get_group('BOS').describe()

# %%
#get_dummies in pandas
# pd.get_dummies(df['month'])
# make date. 
#df['new']= df['early'].map(lambda x : "new"+x)
#df['new']= df['early'].map(lambda x : x*x)

# %%
def plot_histogram(x):
    plt.hist(x, alpha=0.5)
    plt.title("Histogram of '{var_name}'".format(var_name=x.name))
    plt.xlabel("Value")
    plt.ylabel("Frequency")
    plt.show()

# %%
plot_histogram(df['Month'])

# %%
# Plot histograms to show distribution of features by outcome categories
def plot_histogram_dv(x,y):
    plt.hist(list(x[y==0]), alpha=0.5, label='Outcome=0')
    plt.hist(list(x[y==1]), alpha=0.5, label='Outcome=1')
    plt.title("Histogram of '{var_name}' by Outcome Category".format(var_name=x.name))
    plt.xlabel("Value")
    plt.ylabel("Frequency")
    plt.legend(loc='upper right')
    plt.show()

# %%
plot_histogram_dv(df['DistanceGroup'],df['ArrDel15'])

# %%
from matplotlib.pyplot import *
plot(df['Distance'],df['delay'],'v')

# %%
df['temp']=pd.to_numeric(df.DryBulbFarenheit, errors='coerce')
# print(df['temp'].value_counts())
# # df['temp']# # M is missin
df['HourlyPrecip']=df['HourlyPrecip'].str.replace('T', '0.005')
df['HourlyPrecip'].value_counts()
df['precip']=pd.to_numeric(df['HourlyPrecip'], errors='coerce')
# #how much of data is missing
df['precip'].value_counts()
df['precip']=np.where(df['precip'].isnull,0,df['precip'])
df['vis']= pd.to_numeric(df.Visibility, errors='coerce')

# %%
from matplotlib.pyplot import *

plot(df['temp'],df['delay'],'o')

# %%
#how much of data is missing
# df.isnull().sum().sort_values(ascending=False).head()

# %%
## OLS
result = sm.ols(formula ="delay ~ temp+vis+north+Distance", data= df).fit()
print(result.params)
print (result.summary())

# %%
## furture job.  congestion  and dummy for month
